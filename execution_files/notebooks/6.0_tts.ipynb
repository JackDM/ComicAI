# %%
from gtts import gTTS
from pathlib import Path

# %%
def text_to_audio(file_path, output_path, lang='es'):
    # Lee el contenido del archivo de texto
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read().strip()  # Lee y elimina espacios en blanco adicionales
    
    # Verifica si el texto está vacío
    if not text:
        text = "La viñeta solo contiene texto"
    
    # Agrega el encabezado al texto
    header_text = f"La viñeta contiene:    {text}"
    
    # Genera el objeto gTTS con el acento especificado
    tts = gTTS(text=header_text, lang=lang)
    
    # Define el nombre del archivo de salida
    audio_file = output_path.with_suffix('.mp3')
    
    # Crea el directorio de salida si no existe
    audio_file.parent.mkdir(parents=True, exist_ok=True)
    
    # Guarda el archivo de audio
    tts.save(audio_file)
    
    print(f"El archivo de audio se ha guardado como {audio_file}")

def process_directory(input_dir, output_dir, lang='es'):
    input_path = Path(input_dir)
    output_path = Path(output_dir)

    for text_file in input_path.rglob('*.txt'):
        # Calcula la ruta de salida
        relative_path = text_file.relative_to(input_path)
        output_file = output_path / relative_path.with_suffix('.mp3')  # Ajusta la extensión
        text_to_audio(text_file, output_file, lang)

# Directorio de entrada
input_directory_description = r'..\..\data\output\output_description_translate_test'

# Directorio de salida
output_directory = r'..\..\data\output\output_audio_test'

# Llama a la función para procesar el directorio
process_directory(input_directory_description, output_directory)
# Out:
# El archivo de audio se ha guardado como ..\..\data\output\output_audio_test\Chapter01\page1_img\panel_1.mp3
# El archivo de audio se ha guardado como ..\..\data\output\output_audio_test\Chapter01\page1_img\panel_2.mp3
# El archivo de audio se ha guardado como ..\..\data\output\output_audio_test\Chapter01\page1_img\panel_3.mp3
# El archivo de audio se ha guardado como ..\..\data\output\output_audio_test\Chapter01\page1_img\panel_4.mp3
# El archivo de audio se ha guardado como ..\..\data\output\output_audio_test\Chapter01\page1_img\panel_5.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 44
#      41 output_directory = r'..\..\data\output\output_audio_test'
#      43 # Llama a la función para procesar el directorio
# ---> 44 process_directory(input_directory_description, output_directory)
#
# Cell In[10], line 35, in process_directory(input_dir, output_dir, lang)
#      33 relative_path = text_file.relative_to(input_path)
#      34 output_file = output_path / relative_path.with_suffix('.mp3')  # Ajusta la extensión
# ---> 35 text_to_audio(text_file, output_file, lang)
#
# Cell In[10], line 23, in text_to_audio(file_path, output_path, lang)
#      20 audio_file.parent.mkdir(parents=True, exist_ok=True)
#      22 # Guarda el archivo de audio
# ---> 23 tts.save(audio_file)
#      25 print(f"El archivo de audio se ha guardado como {audio_file}")
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\gtts\tts.py:335, in gTTS.save(self, savefile)
#     325 """Do the TTS API request and write result to file.
#     326
#     327 Args:
#    (...)
#     332
#     333 """
#     334 with open(str(savefile), "wb") as f:
# --> 335     self.write_to_fp(f)
#     336     f.flush()
#     337     log.debug("Saved to %s", savefile)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\gtts\tts.py:316, in gTTS.write_to_fp(self, fp)
#     304 """Do the TTS API request(s) and write bytes to a file-like object.
#     305
#     306 Args:
#    (...)
#     312
#     313 """
#     315 try:
# --> 316     for idx, decoded in enumerate(self.stream()):
#     317         fp.write(decoded)
#     318         log.debug("part-%i written to %s", idx, fp)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\gtts\tts.py:268, in gTTS.stream(self)
#     265 try:
#     266     with requests.Session() as s:
#     267         # Send request
# --> 268         r = s.send(
#     269             request=pr,
#     270             verify=False,
#     271             proxies=urllib.request.getproxies(),
#     272             timeout=self.timeout,
#     273         )
#     275     log.debug("headers-%i: %s", idx, r.request.headers)
#     276     log.debug("url-%i: %s", idx, r.request.url)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
