# %%
import os
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
import sentencepiece as spm

# %%
# Verificar si CUDA está disponible
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {device}")

# Cargar el modelo preentrenado y el tokenizador
tokenizer = T5Tokenizer.from_pretrained("vgaraujov/t5-base-spanish")
model = T5ForConditionalGeneration.from_pretrained("vgaraujov/t5-base-spanish").to(device)

# Función para corregir texto
def correct_text(text):
    input_text = f"corrige: {text}"
    inputs = tokenizer(input_text, return_tensors="pt", max_length=512, truncation=True).to(device)
    outputs = model.generate(inputs.input_ids)
    corrected_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return corrected_text

# Directorios de entrada y salida
input_dir = r'..\..\data\output\output_description_translate_test'
output_dir = r'..\..\data\output\output_correct_text'

# Función para procesar un archivo
def process_file(input_file_path, output_file_path):
    with open(input_file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    # Imprimir el texto original
    print(f'Texto original:\n{text}\n')

    # Corregir el texto
    corrected_text = correct_text(text)

    # Imprimir la corrección
    print(f'Texto corregido:\n{corrected_text}\n')

    # Guardar el texto corregido en el archivo de salida
    with open(output_file_path, 'w', encoding='utf-8') as file:
        file.write(corrected_text)

    print('..............................................')

# Recorrer recursivamente el directorio de entrada
for root, dirs, files in os.walk(input_dir):
    for file in files:
        if file.lower().endswith('.txt'):
            # Obtener la ruta completa del archivo de entrada
            input_file_path = os.path.join(root, file)

            # Crear la ruta de salida correspondiente
            relative_path = os.path.relpath(root, input_dir)
            output_dir_path = os.path.join(output_dir, relative_path)
            os.makedirs(output_dir_path, exist_ok=True)

            # Crear la ruta completa del archivo de salida
            output_file_path = os.path.join(output_dir_path, file)

            # Procesar el archivo
            process_file(input_file_path, output_file_path)
            print(f'Procesado y guardado: {output_file_path}')
# Out:
# Usando dispositivo: cpu
# Texto original:
# Una persona está mirando una casa en un bosque.
# e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\generation\utils.py:1168: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Texto corregido:
# desur ensen ensen ensen ensen ensen
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page1_img\panel_1.txt
# Texto original:
# La cara de Edrei se ve molesta y triste.
#
# Texto corregido:
# . ::. La cara.::
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page1_img\panel_2.txt
# Texto original:
# Escoria sostiene el brazo de edrei con expresión triste. edrei parece asustado
#
# Texto corregido:
# el brazo el brazo de edrei con expresión triste. edrei
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page1_img\panel_3.txt
# Texto original:
# Escoria se da vuelta y mira a su izquierda con expresión triste.
#
# Texto corregido:
# que que de la a su derecha con expresión triste se da vuelta para abajo
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page1_img\panel_4.txt
# Texto original:
# Escoria sonríe con una cara graciosa.
#
# Texto corregido:
# ... con una cara graciosa Escoria es graciosa
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page1_img\panel_5.txt
# Texto original:
# Escoria y edrei están sentados en una repisa. Escoria mira a su derecha con expresión triste. edrei es rechazado
#
# Texto corregido:
# sa. a su derecha..s... triste
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page2_img\panel_1.txt
# Texto original:
# Hay una piedra en el suelo con una sombra.
#
# Texto corregido:
# de la tierra la piedra la piedra la piedra la piedra la piedra la piedra la piedra la
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page2_img\panel_2.txt
# Texto original:
# Escoria la mira con expresión triste. un pueblo está al fondo
#
# Texto corregido:
# . al. al al pueblo. pueblo. triste.
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page2_img\panel_3.txt
# Texto original:
# La cara de Edrei se ve molesta y triste.
#
# Texto corregido:
# . ::. La cara.::
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page2_img\panel_4.txt
# Texto original:
# una mano sostiene un libro
#
# Texto corregido:
# de de de de, una de de de
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page2_img\panel_5.txt
# Texto original:
# Edrei sostiene una varita mágica y lanza un hechizo. edrei parece asustado
#
# Texto corregido:
# . edre y lanza un hechizo. edre. edre. e
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_1.txt
# Texto original:
# edrei y escoria caminan sosteniendo sus varitas. Escoria sonríe y sostiene su varita.
#
# Texto corregido:
# .a an sosteniendo sus manos.ean sosteniendo sus manos.ean sosteniendo sus
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_2.txt
# Texto original:
# un hombre y una niña caminan por una playa de arena
#
# Texto corregido:
# una mujer una de. de. una mujer.
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_3.txt
# Texto original:
# muchas marcas en el suelo
#
# Texto corregido:
# . en el.. las. las.,
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_4.txt
# Texto original:
# Edrei mira asustado al lado de Escoria. edrei parece sorprendido
#
# Texto corregido:
# ria. al lado.. edrei mira asustado está
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_5.txt
# Texto original:
# Escoria vuelve la cabeza hacia atrás y mira con expresión triste.
#
# Texto corregido:
# . y de de que triste triste triste de.
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_6.txt
# Texto original:
# una mano empuja a edrei. edrei cae contra una pared
#
# Texto corregido:
# . a una. a. de. una contra una.
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_7.txt
# Texto original:
# Escoria levanta su varita mágica. Edrei parece asustado y sorprendido. edrei parece sorprendido
#
# Texto corregido:
# ta. Era y mágica. Edrei asustado.. E
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page3_img\panel_8.txt
# Texto original:
# un caballo corre en una arena con la gente mirando
#
# Texto corregido:
# con arena con en en en en en en en en en en en en
#
# ..............................................
# Procesado y guardado: ..\..\data\output\output_correct_text\Chapter01\page4_img\panel_1.txt
# Texto original:
# una bota con capa muestra los dientes y tiene expresión de dolor
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 57
#      54 output_file_path = os.path.join(output_dir_path, file)
#      56 # Procesar el archivo
# ---> 57 process_file(input_file_path, output_file_path)
#      58 print(f'Procesado y guardado: {output_file_path}')
#
# Cell In[3], line 30, in process_file(input_file_path, output_file_path)
#      27 print(f'Texto original:\n{text}\n')
#      29 # Corregir el texto
# ---> 30 corrected_text = correct_text(text)
#      32 # Imprimir la corrección
#      33 print(f'Texto corregido:\n{corrected_text}\n')
#
# Cell In[3], line 13, in correct_text(text)
#      11 input_text = f"corrige: {text}"
#      12 inputs = tokenizer(input_text, return_tensors="pt", max_length=512, truncation=True).to(device)
# ---> 13 outputs = model.generate(inputs.input_ids)
#      14 corrected_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
#      15 return corrected_text
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\generation\utils.py:1758, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1750     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1751         input_ids=input_ids,
#    1752         expand_size=generation_config.num_return_sequences,
#    1753         is_encoder_decoder=self.config.is_encoder_decoder,
#    1754         **model_kwargs,
#    1755     )
#    1757     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1758     result = self._sample(
#    1759         input_ids,
#    1760         logits_processor=prepared_logits_processor,
#    1761         logits_warper=prepared_logits_warper,
#    1762         stopping_criteria=prepared_stopping_criteria,
#    1763         generation_config=generation_config,
#    1764         synced_gpus=synced_gpus,
#    1765         streamer=streamer,
#    1766         **model_kwargs,
#    1767     )
#    1769 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1770     # 11. prepare logits warper
#    1771     prepared_logits_warper = (
#    1772         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1773     )
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\generation\utils.py:2397, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2394 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2396 # forward pass to get next token
# -> 2397 outputs = self(
#    2398     **model_inputs,
#    2399     return_dict=True,
#    2400     output_attentions=output_attentions,
#    2401     output_hidden_states=output_hidden_states,
#    2402 )
#    2404 if synced_gpus and this_peer_finished:
#    2405     continue  # don't waste resources running the code we don't need
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\models\t5\modeling_t5.py:1740, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1737         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1739 # Decode
# -> 1740 decoder_outputs = self.decoder(
#    1741     input_ids=decoder_input_ids,
#    1742     attention_mask=decoder_attention_mask,
#    1743     inputs_embeds=decoder_inputs_embeds,
#    1744     past_key_values=past_key_values,
#    1745     encoder_hidden_states=hidden_states,
#    1746     encoder_attention_mask=attention_mask,
#    1747     head_mask=decoder_head_mask,
#    1748     cross_attn_head_mask=cross_attn_head_mask,
#    1749     use_cache=use_cache,
#    1750     output_attentions=output_attentions,
#    1751     output_hidden_states=output_hidden_states,
#    1752     return_dict=return_dict,
#    1753 )
#    1755 sequence_output = decoder_outputs[0]
#    1757 # Set device for model parallelism
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\models\t5\modeling_t5.py:1107, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1092     layer_outputs = self._gradient_checkpointing_func(
#    1093         layer_module.forward,
#    1094         hidden_states,
#    (...)
#    1104         output_attentions,
#    1105     )
#    1106 else:
# -> 1107     layer_outputs = layer_module(
#    1108         hidden_states,
#    1109         attention_mask=extended_attention_mask,
#    1110         position_bias=position_bias,
#    1111         encoder_hidden_states=encoder_hidden_states,
#    1112         encoder_attention_mask=encoder_extended_attention_mask,
#    1113         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1114         layer_head_mask=layer_head_mask,
#    1115         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1116         past_key_value=past_key_value,
#    1117         use_cache=use_cache,
#    1118         output_attentions=output_attentions,
#    1119     )
#    1121 # layer_outputs is a tuple with:
#    1122 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1123 if use_cache is False:
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\models\t5\modeling_t5.py:717, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     714 else:
#     715     query_length = None
# --> 717 cross_attention_outputs = self.layer[1](
#     718     hidden_states,
#     719     key_value_states=encoder_hidden_states,
#     720     attention_mask=encoder_attention_mask,
#     721     position_bias=encoder_decoder_position_bias,
#     722     layer_head_mask=cross_attn_layer_head_mask,
#     723     past_key_value=cross_attn_past_key_value,
#     724     query_length=query_length,
#     725     use_cache=use_cache,
#     726     output_attentions=output_attentions,
#     727 )
#     728 hidden_states = cross_attention_outputs[0]
#     730 # clamp inf values to enable fp16 training
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\models\t5\modeling_t5.py:628, in T5LayerCrossAttention.forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions)
#     615 def forward(
#     616     self,
#     617     hidden_states,
#    (...)
#     625     output_attentions=False,
#     626 ):
#     627     normed_hidden_states = self.layer_norm(hidden_states)
# --> 628     attention_output = self.EncDecAttention(
#     629         normed_hidden_states,
#     630         mask=attention_mask,
#     631         key_value_states=key_value_states,
#     632         position_bias=position_bias,
#     633         layer_head_mask=layer_head_mask,
#     634         past_key_value=past_key_value,
#     635         use_cache=use_cache,
#     636         query_length=query_length,
#     637         output_attentions=output_attentions,
#     638     )
#     639     layer_output = hidden_states + self.dropout(attention_output[0])
#     640     outputs = (layer_output,) + attention_output[1:]  # add attentions if we output them
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File e:\ANACONDA\envs\SATURDAYS-2\Lib\site-packages\transformers\models\t5\modeling_t5.py:524, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     519 value_states = project(
#     520     hidden_states, self.v, key_value_states, past_key_value[1] if past_key_value is not None else None
#     521 )
#     523 # compute scores
# --> 524 scores = torch.matmul(
#     525     query_states, key_states.transpose(3, 2)
#     526 )  # equivalent of torch.einsum("bnqd,bnkd->bnqk", query_states, key_states), compatible with onnx op>9
#     528 if position_bias is None:
#     529     if not self.has_relative_attention_bias:
#
# KeyboardInterrupt:
